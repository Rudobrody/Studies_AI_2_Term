# %% [markdown]
# # 0.0 Task

# %% [markdown]
# Zaimplementuj algorytm genetyczny z uwzględnieniem poniższych wymagań:
#
# * kodowanie binarne bądź dyskretne/ciągłe genotypu
# * parametryzacja długości genotypu, wielkości populacji
# * krzyżowanie k-punktowe z prawdopodobieństwem pk,
# * losowanie locusów bez zwracania mutacja m-punktowa z prawdopodobieństwem pm,
# * losowanie locusów bez zwracania selekcja:
# * rankingowa: n najlepszych osobników zastępuje w populacji n najgorszych
# * koło ruletki z uwzględnieniem funkcji transformującej wartości funkcji przystosowania
# * warunek stopu: liczba pokoleń, opcjonalnie docelowa wartość funkcji przystosowania, % najlepszych osobników w populacji
# Użyj algorytmu do optymalizacji ANFIS.

# %% [markdown]
# # 0.1 Theory about genetic algorithm

# %% [markdown]
# It is a search method inspired directly by Charles Darwin's theory of evolution: Survival of the Fittest.
# 1. Initialization - creating the first generation, starts by creating a random population of solutions (**chromosomes**)
# 2. Then repeat for each generation:
# * Evaluate fitness of each individual
# * Select the best individuals as parents
# * Crossover parent to create children
# * Mutate children with a small chance
# * Termination condition met?
# 3. When the condtion for stop was filled, give a solution

# %% [markdown]
# # 0.2 Discrete vs. Continious

# %% [markdown]
# This is fundamental concept of GA, the representation of the gene dictates how the crossover and mutation operators must work.
#
# **Discrete Gene** represents a parameter that can only take on a value from a **finite, specific set of option**. The values are distinct and separate, not on a continious spectrum. What it represensts: categorical choices, integer counts or selections from a list
#
# With discrete genes works crossover: **One-point or Two-point Crossover** I can randomly select a gene and replace its value with another valid option from its set.
#
# **Continious gene** represents a parameter that can take on any real-valued number within a given range. Simple swapping doesn't work as well. Instead, **blending or arithemtic crossover** methods are used. In mutation you can't just swap it for another value. Instead we can add a small amount of random noise. We can use Gaussian Mutation.

# %% [markdown]
# # 0.3 Blend Crossover

# %% [markdown]
# What is a **Blend Crossover**? Creates a child gene that is a random value within a range defined by the two parent genes. Example:
# Parent 1 Gene: 0.01
# Parent 2 Gene: 0.05
# Child Gene will be a random number between 0.01 and 0.05

# %% [markdown]
# # 0.4 Arithmetic crossover

# %% [markdown]
# What is a **Arithmetic Crossover**? Creates a child gene that is a weigted average of the parents genes.
#
# $Gene_{child}  = \alpha * Gene_{parent1} + (1-\alpha) * Gene_{parent2}$
# where $\alpha$ is a random weight.

# %% [markdown]
# # 0.5 Gaussian mutation

# %% [markdown]
# In Gaussian mutation we add a random number from a Gaussian (normal) distribution with a mean of 0 and a small standard deviation.
# Example:
# Before mutation: 0.045
# After mutation: 0.045 + random_gaussian_noise() = 0.042

# %% [markdown]
# ## 1.0 Adapting the Genetic Algorithm for ANFIS

# %% [markdown]
# Population of potential schedules. Some are terrible, with a lot of wastted time. Some are pretty good. The schedules with the shortest completion time are more likely to be selected as 'parents'. Between parents like this we would like to make a crossover. Random mutations to ensure we don't get stuck.
# **Gene**: A single operation that needs to be scheduled. Must be uniquely identify, for example (task_id, operation_index_within_task).
# **Chromosome**: A potential solution. A chromosome will be a single, flat list containing all the genes (operations) in a specific order.
#
# Example:
# task 0 : [(T0, R0), (T0, R1)]
# task 1: [(T1, R0), (T1, R1)]
#
# Chromosome would be a permutation: [(T0,R0), (T1,R0), (T1, R1), (T0,R1)]
#
# Fitness function will take a chromosome as an input and calculate fitness score. our goal is to minimize.

# %%
import pandas as pd
import numpy as np 
import matplotlib
import matplotlib.pyplot as plt
import math
import random
from dataclasses import dataclass
from typing import List, Tuple


@dataclass(frozen=True) # Frozen=True makes instances of this class immutable
class Operation:
    task_id: int #  
    op_id: int # Every task has 11 operations 
    resource: int
    duration: int


class JobShopData:
    """A dedicated class to hold and provide access to data"""
    def __init__(self, path: str):
        df = pd.read_excel('GA_task.xlsx', header=[0, 1])
        
        # A list of all unique operations (genes)
        self.operations: List[Operation] = []
        
        # A structured list of tasks for easy lookup
        self.tasks: List[List[Operation]] = []
        
        # Loop trough task
        for task_id, task_df in df.groupby(level=0, axis=1): # lvl 0 - ID, level 1 - R/T, axis 0 - rows, axis 1 - columns
            # for each task I create a list of its operations
            current_task_operation = []

            r_col = task_df.xs("R", level=1, axis=1).iloc[:,0] # xs stands for cross section, level 0 is the task ID, level 1 is either 'R' or 'T', axis=1 columns
            t_col = task_df.xs("T", level=1, axis=1).iloc[:,0]

            # Loop trough the operations for this task
            op_id_counter = 0
            for resource, time in zip(r_col, t_col):
                # Create operation object
                op = Operation(
                    task_id=task_id,
                    op_id=op_id_counter,
                    resource=resource,
                    duration=time
                )

                # Append new object to the global gene pool
                self.operations.append(op)

                # Append it to the list for the current task
                current_task_operation.append(op)

                op_id_counter += 1

            # After processing all operations for this task and its list to self.tasks
            self.tasks.append(current_task_operation)    

        self.num_tasks = len(self.tasks)
        all_resources = {op.resource for op in self.operations}
        self.num_resources = len(all_resources)
        self.num_operational_total = len(self.operations)

        print(f"Data loaded... \n\nNumber of tasks: {self.num_tasks}\nTootal number of operations: {self.num_operational_total}\nNumber of resources: {self.num_resources}\n\n")

# %%
dataload = JobShopData(path='GA_task.xlsx',)
# Out:
# Data loaded...
#
# Number of tasks: 50
# Tootal number of operations: 550
# Number of resources: 10
# C:\Users\pawel\AppData\Local\Temp\ipykernel_44936\417011900.py:31: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   for task_id, task_df in df.groupby(level=0, axis=1): # lvl 0 - ID, level 1 - R/T, axis 0 - rows, axis 1 - columns

# %% [markdown]
# # 2.0 Fitness function

# %%
class Scheduler:
    """
    Calculates the fitness of a single chromosome.
    """
    def __init__(self, data: JobShopData):
        """
        Initializes the Scheduler with the problem data. 

        Args:
            data (JobShopData): The loaded job shop problem data.
        """
        self.data = data
    
    def calculate_fitness(self, chromosome: List[Operation]) -> float:
        """
        Calculate the makespan for a given chromosome and returns a fitness score.

        Args:
            chromosome (List[Operation]): A permutation of all operations, representing a schedule's priority list

        Returns:
            float: The fitness score, calculated as 1.0 makespan.
        """
        # The time when resource will be available
        resource_end_times = np.zeros(self.data.num_resources + 1) # Resources are indexed from 1 
        
        # Times when task are over 
        task_end_times = np.zeros(self.data.num_tasks + 1)


        for op in chromosome:
            # Time the task is ready, time of the end of previous operation
            task_ready_time = task_end_times[op.task_id] # In first iteration value is zero

            # Time when resource is available
            resource_ready_time = resource_end_times[op.resource] # In first iteration value is zero

            # An operation can only start when task and resource is ready
            start_time = max(task_ready_time, resource_ready_time)
            end_time = start_time + op.duration

            # Update
            task_end_times[op.task_id] = end_time
            resource_end_times[op.resource] = end_time
        
        # The longest task took:
        total_makespan = np.max(task_end_times) 

        return 1.0 / total_makespan

# %%
scheduler = Scheduler(dataload)

basic_chromosome = dataload.operations

fitness = scheduler.calculate_fitness(basic_chromosome)
makespan = 1 / fitness

print("Scheduler test \n")
print(f"Fitness of basic is: {fitness} and makespan: {makespan}")
# Out:
# Scheduler test
#
# Fitness of basic is: 8.692628650904033e-05 and makespan: 11504.0

# %% [markdown]
# # 3.0 Genetic Algorithm

# %%
class GeneticAlgorithm:
    """
    A genetic algorithm implementation.
    """
    def __init__(self,
                data: JobShopData,
                scheduler: Scheduler,
                population_size: int = 350,
                crossover_rate: float = 0.8,
                mutation_rate: float = 0.15,
                selection_method: str = "rank"):
        """
        Initializes instances of class GeneticAlgorithm
        
        Args: 
            data (JobShopData): The job shop data containing operations to be scheduled.
            scheduler (Scheduler): Component that calculates the fitness of chromosomes.
            population_size (int): Number of individuals (chromosomes) are in the population
            crossover_rate (float): The probability that two selected parents will actually breed.
            mutation_rate (float): The probability that an individual gene (operation) in a chromosome will be mutated. 
            selection_method (str): default="roulette" The method used to select parent from the population
        """
        self.data = data
        self.scheduler = scheduler
        self.population_size = population_size
        self.crossover_rate = crossover_rate
        self.mutation_rate = mutation_rate
        self.population: List[List[Operation]] = []
        self.best_chromosome = None
        self.best_fitness = 0
        
        if selection_method == "roulette":
            self.selection_func = self._selection_roulette
        elif selection_method =="rank": 
            self.selection_func = self._selection_rank
        else:
            raise ValueError("Unknown selection method")

    
    def _create_initial_population(self):
        # Empty list for new population
        new_population = []

        # For each individual
        for population in range(self.population_size):
            # Create a new chromosome
            chromosome = self.data.operations.copy()

            # Schuffle this copy to create a random permuattion
            random.shuffle(chromosome)

            # Add shuffled chromosome to new population
            new_population.append(chromosome)
        
        # Exchanging population
        self.population = new_population

    
    def _selection_roulette(self, fitness_scores: List[float]) -> List[Operation]:
        """
        Selects one parent using Roulette Wheel Selection
        
        Notes:
        This method will have problems when the fitnesses differs very much. 
        """
        # Sum of all fitness scores
        total_fitness = sum(fitness_scores)

        # Picking random number
        pick = random.uniform(0, total_fitness)

        current_sum = 0
        for i, fitness in enumerate(fitness_scores):
            current_sum += fitness
            if current_sum > pick:
                return self.population[i]
        
        
        return self.population[-1]
    

    def _selection_rank(self, fitness_scores: List[float]) -> List[Operation]:
        """Selects one parrent using Rank Selection"""
        ranks = np.argsort(fitness_scores)
        total_rank = self.population_size * (self.population_size + 1) / 2 # mathematical shortcut SUM = N * (N + 1) / 2, formula of sum of the first N integers
        # total rank is like adding weights 1, 2, 3, 4, 5, 6 
        
        pick = random.uniform(0, total_rank)
        
        current_sum = 0
        # ranks tells index of the individual at each rank, so rank[0] is the worst, rank[n-1] is best
        for i, individual_index in enumerate(ranks):
            current_sum += (i + 1)
            if current_sum > pick:
                return self.population[individual_index]
            
        return self.population[ranks[-1]]
    

    def _crossover(self, parent1: List[Operation], parent2: List[Operation]) -> Tuple[List[Operation], List[Operation]]:
        """
        Performs Order Crossover, creates two children
        Notes: 
            Pay attention that in this case we can't use single-point crossover - cut two parent in half and swap the tails because some operation will be missing
            So we have to use crossover method for permutations - it is called order crossover
        """
        size = len(parent1)

        def create_child(p1, p2):
            child = [None] * size
            point1, point2 = random.sample(range(size), 2) # we cant use uniform because it returns float 
            
            # we have to sort this point 
            start = min(point1, point2)
            end = max(point1, point2)

            # Copy the slice from parent1 directly into child1
            slice_from_parent1 = p1[start:end]
            child[start:end] = slice_from_parent1

            # Use a set for checking which geners are already in the child
            genes_in_slice = set(slice_from_parent1)

            # Fill the remaining slots from the second parent (p2)
            p2_idx = end # Starting from the end of the slice
            child_idx = end
            
            # Loop unitl the child is full
            while None in child:
                # If the gene from parent2 is not in the child's slice
                if p2[p2_idx] not in genes_in_slice:
                    # Add it to the child
                    child[child_idx] = p2[p2_idx]

                    child_idx = (child_idx + 1) % size # Why this line it's not over loop? because in case when the gen is in the slice, position to fill
                    # shouldn't move
                p2_idx = (p2_idx + 1) % size

            return child

        child1 = create_child(parent1, parent2)
        child2 = create_child(parent2, parent1)

        return child1, child2

    def _mutation(self, chromosome: List[Operation]):
        """Performs Swap Mutation on a chromosome."""
        if random.random() < self.mutation_rate:
            # Select two indeces for swap
            idx1, idx2 = random.sample(range(len(chromosome)), 2)

            # Swap operations
            chromosome[idx1], chromosome[idx2] = chromosome[idx2], chromosome[idx1]


    def run(self, num_generations: int):
        # Create new popultion
        self._create_initial_population()

        for gen in range(num_generations):
            # Evolution
            fitness_scores = [self.scheduler.calculate_fitness(chromo) for chromo in self.population]
            
            # Track best solution
            index_of_best_in_gen = np.argmax(fitness_scores) # argmax returns index of max value
            if fitness_scores[index_of_best_in_gen] > self.best_fitness:
                self.best_fitness = fitness_scores[index_of_best_in_gen]
                self.best_chromosome = self.population[index_of_best_in_gen].copy()

            # Create nexxt generation
            next_generation = []

            # Elitism
            best_in_gen_chromosome = self.population[index_of_best_in_gen]
            next_generation.append(best_in_gen_chromosome.copy())


            while len(next_generation) < self.population_size:
                # Selection
                parent1 = self.selection_func(fitness_scores)
                parent2 = self.selection_func(fitness_scores)

                # Crossover
                if random.random() < self.crossover_rate:
                    new_parent1, new_parent2 = self._crossover(parent1, parent2)
                else:
                    new_parent1, new_parent2 = parent1.copy(), parent2.copy()

                # Mutation
                self._mutation(new_parent1)
                self._mutation(new_parent2)

                offspring1 = new_parent1.copy()
                offspring2 = new_parent2.copy()

                next_generation.append(offspring1)

                # Making sure not to cross tthe limit of population size
                if len(next_generation) < self.population_size:
                    next_generation.append(offspring2)

            self.population = next_generation

            if (gen + 1) % 10 == 0:
                print(f"Generation {gen + 1}/{num_generations}. Best fitness: {self.best_fitness}")

        return self.best_chromosome, self.best_fitness

# %%
gen_alg = GeneticAlgorithm(dataload, scheduler)
best_chromosome, best_fitness = gen_alg.run(num_generations=5000)
makespan = 1 / best_fitness
print(f"Best fitness score is equal:{best_fitness} and makespan: {makespan}")
# Out:
# Generation 10/5000. Best fitness: 0.000449842555105713
# Generation 20/5000. Best fitness: 0.00045330915684496827
# Generation 30/5000. Best fitness: 0.00046382189239332097
# Generation 40/5000. Best fitness: 0.00046992481203007516
# Generation 50/5000. Best fitness: 0.00047192071731949034
# Generation 60/5000. Best fitness: 0.00047192071731949034
# Generation 70/5000. Best fitness: 0.00047192071731949034
# Generation 80/5000. Best fitness: 0.00047192071731949034
# Generation 90/5000. Best fitness: 0.00047192071731949034
# Generation 100/5000. Best fitness: 0.00047505938242280285
# Generation 110/5000. Best fitness: 0.00047505938242280285
# Generation 120/5000. Best fitness: 0.00047505938242280285
# Generation 130/5000. Best fitness: 0.00047596382674916705
# Generation 140/5000. Best fitness: 0.00047596382674916705
# Generation 150/5000. Best fitness: 0.0004768717215069146
# Generation 160/5000. Best fitness: 0.0004768717215069146
# Generation 170/5000. Best fitness: 0.0004768717215069146
# Generation 180/5000. Best fitness: 0.0004768717215069146
# Generation 190/5000. Best fitness: 0.0004768717215069146
# Generation 200/5000. Best fitness: 0.0004768717215069146
# Generation 210/5000. Best fitness: 0.0004768717215069146
# Generation 220/5000. Best fitness: 0.0004768717215069146
# Generation 230/5000. Best fitness: 0.0004768717215069146
# Generation 240/5000. Best fitness: 0.0004768717215069146
# Generation 250/5000. Best fitness: 0.0004768717215069146
# Generation 260/5000. Best fitness: 0.0004786979415988511
# Generation 270/5000. Best fitness: 0.0004786979415988511
# Generation 280/5000. Best fitness: 0.0004786979415988511
# Generation 290/5000. Best fitness: 0.00048146364949446316
# Generation 300/5000. Best fitness: 0.000482392667631452
# Generation 310/5000. Best fitness: 0.000482392667631452
# Generation 320/5000. Best fitness: 0.000482392667631452
# Generation 330/5000. Best fitness: 0.000482392667631452
# Generation 340/5000. Best fitness: 0.000482392667631452
# Generation 350/5000. Best fitness: 0.000482392667631452
# Generation 360/5000. Best fitness: 0.000482392667631452
# Generation 370/5000. Best fitness: 0.000482392667631452
# Generation 380/5000. Best fitness: 0.000482392667631452
# Generation 390/5000. Best fitness: 0.000482392667631452
# Generation 400/5000. Best fitness: 0.000482392667631452
# Generation 410/5000. Best fitness: 0.000482392667631452
# Generation 420/5000. Best fitness: 0.000482392667631452
# Generation 430/5000. Best fitness: 0.000482392667631452
# Generation 440/5000. Best fitness: 0.000482392667631452
# Generation 450/5000. Best fitness: 0.000482392667631452
# Generation 460/5000. Best fitness: 0.000482392667631452
# Generation 470/5000. Best fitness: 0.000482392667631452
# Generation 480/5000. Best fitness: 0.000482392667631452
# Generation 490/5000. Best fitness: 0.000482392667631452
# Generation 500/5000. Best fitness: 0.000482392667631452
# Generation 510/5000. Best fitness: 0.000482392667631452
# Generation 520/5000. Best fitness: 0.000482392667631452
# Generation 530/5000. Best fitness: 0.000482392667631452
# Generation 540/5000. Best fitness: 0.000482392667631452
# Generation 550/5000. Best fitness: 0.000482392667631452
# Generation 560/5000. Best fitness: 0.000482392667631452
# Generation 570/5000. Best fitness: 0.000482392667631452
# Generation 580/5000. Best fitness: 0.000482392667631452
# Generation 590/5000. Best fitness: 0.000482392667631452
# Generation 600/5000. Best fitness: 0.000482392667631452
# Generation 610/5000. Best fitness: 0.000482392667631452
# Generation 620/5000. Best fitness: 0.000482392667631452
# Generation 630/5000. Best fitness: 0.000482392667631452
# Generation 640/5000. Best fitness: 0.000482392667631452
# Generation 650/5000. Best fitness: 0.000482392667631452
# Generation 660/5000. Best fitness: 0.000482392667631452
# Generation 670/5000. Best fitness: 0.000482392667631452
# Generation 680/5000. Best fitness: 0.000482392667631452
# Generation 690/5000. Best fitness: 0.000482392667631452
# Generation 700/5000. Best fitness: 0.000482392667631452
# Generation 710/5000. Best fitness: 0.000482392667631452
# Generation 720/5000. Best fitness: 0.000482392667631452
# Generation 730/5000. Best fitness: 0.000482392667631452
# Generation 740/5000. Best fitness: 0.000482392667631452
# Generation 750/5000. Best fitness: 0.000482392667631452
# Generation 760/5000. Best fitness: 0.000482392667631452
# Generation 770/5000. Best fitness: 0.000482392667631452
# Generation 780/5000. Best fitness: 0.000482392667631452
# Generation 790/5000. Best fitness: 0.000482392667631452
# Generation 800/5000. Best fitness: 0.000482392667631452
# Generation 810/5000. Best fitness: 0.000482392667631452
# Generation 820/5000. Best fitness: 0.000482392667631452
# Generation 830/5000. Best fitness: 0.000482392667631452
# Generation 840/5000. Best fitness: 0.000482392667631452
# Generation 850/5000. Best fitness: 0.000482392667631452
# Generation 860/5000. Best fitness: 0.000482392667631452
# Generation 870/5000. Best fitness: 0.000482392667631452
# Generation 880/5000. Best fitness: 0.000482392667631452
# Generation 890/5000. Best fitness: 0.000482392667631452
# Generation 900/5000. Best fitness: 0.000482392667631452
# Generation 910/5000. Best fitness: 0.000482392667631452
# Generation 920/5000. Best fitness: 0.000482392667631452
# Generation 930/5000. Best fitness: 0.000482392667631452
# Generation 940/5000. Best fitness: 0.000482392667631452
# Generation 950/5000. Best fitness: 0.000482392667631452
# Generation 960/5000. Best fitness: 0.000482392667631452
# Generation 970/5000. Best fitness: 0.000482392667631452
# Generation 980/5000. Best fitness: 0.000482392667631452
# Generation 990/5000. Best fitness: 0.000482392667631452
# Generation 1000/5000. Best fitness: 0.000482392667631452
# Generation 1010/5000. Best fitness: 0.000482392667631452
# Generation 1020/5000. Best fitness: 0.000482392667631452
# Generation 1030/5000. Best fitness: 0.000482392667631452
# Generation 1040/5000. Best fitness: 0.000482392667631452
# Generation 1050/5000. Best fitness: 0.000482392667631452
# Generation 1060/5000. Best fitness: 0.000482392667631452
# Generation 1070/5000. Best fitness: 0.000482392667631452
# Generation 1080/5000. Best fitness: 0.000482392667631452
# Generation 1090/5000. Best fitness: 0.000482392667631452
# Generation 1100/5000. Best fitness: 0.000482392667631452
# Generation 1110/5000. Best fitness: 0.000482392667631452
# Generation 1120/5000. Best fitness: 0.000482392667631452
# Generation 1130/5000. Best fitness: 0.000482392667631452
# Generation 1140/5000. Best fitness: 0.000482392667631452
# Generation 1150/5000. Best fitness: 0.000482392667631452
# Generation 1160/5000. Best fitness: 0.000482392667631452
# Generation 1170/5000. Best fitness: 0.000482392667631452
# Generation 1180/5000. Best fitness: 0.000482392667631452
# Generation 1190/5000. Best fitness: 0.000482392667631452
# Generation 1200/5000. Best fitness: 0.000482392667631452
# Generation 1210/5000. Best fitness: 0.000482392667631452
# Generation 1220/5000. Best fitness: 0.000482392667631452
# Generation 1230/5000. Best fitness: 0.000482392667631452
# Generation 1240/5000. Best fitness: 0.000482392667631452
# Generation 1250/5000. Best fitness: 0.000482392667631452
# Generation 1260/5000. Best fitness: 0.000482392667631452
# Generation 1270/5000. Best fitness: 0.000482392667631452
# Generation 1280/5000. Best fitness: 0.000482392667631452
# Generation 1290/5000. Best fitness: 0.000482392667631452
# Generation 1300/5000. Best fitness: 0.000482392667631452
# Generation 1310/5000. Best fitness: 0.000482392667631452
# Generation 1320/5000. Best fitness: 0.000482392667631452
# Generation 1330/5000. Best fitness: 0.000482392667631452
# Generation 1340/5000. Best fitness: 0.000482392667631452
# Generation 1350/5000. Best fitness: 0.000482392667631452
# Generation 1360/5000. Best fitness: 0.000482392667631452
# Generation 1370/5000. Best fitness: 0.000482392667631452
# Generation 1380/5000. Best fitness: 0.000482392667631452
# Generation 1390/5000. Best fitness: 0.000482392667631452
# Generation 1400/5000. Best fitness: 0.000482392667631452
# Generation 1410/5000. Best fitness: 0.000482392667631452
# Generation 1420/5000. Best fitness: 0.000482392667631452
# Generation 1430/5000. Best fitness: 0.000482392667631452
# Generation 1440/5000. Best fitness: 0.000482392667631452
# Generation 1450/5000. Best fitness: 0.000482392667631452
# Generation 1460/5000. Best fitness: 0.000482392667631452
# Generation 1470/5000. Best fitness: 0.000482392667631452
# Generation 1480/5000. Best fitness: 0.000482392667631452
# Generation 1490/5000. Best fitness: 0.000482392667631452
# Generation 1500/5000. Best fitness: 0.000482392667631452
# Generation 1510/5000. Best fitness: 0.000482392667631452
# Generation 1520/5000. Best fitness: 0.000482392667631452
# Generation 1530/5000. Best fitness: 0.000482392667631452
# Generation 1540/5000. Best fitness: 0.000482392667631452
# Generation 1550/5000. Best fitness: 0.000482392667631452
# Generation 1560/5000. Best fitness: 0.000482392667631452
# Generation 1570/5000. Best fitness: 0.000482392667631452
# Generation 1580/5000. Best fitness: 0.000482392667631452
# Generation 1590/5000. Best fitness: 0.000482392667631452
# Generation 1600/5000. Best fitness: 0.000482392667631452
# Generation 1610/5000. Best fitness: 0.000482392667631452
# Generation 1620/5000. Best fitness: 0.000482392667631452
# Generation 1630/5000. Best fitness: 0.000482392667631452
# Generation 1640/5000. Best fitness: 0.000482392667631452
# Generation 1650/5000. Best fitness: 0.000482392667631452
# Generation 1660/5000. Best fitness: 0.000482392667631452
# Generation 1670/5000. Best fitness: 0.000482392667631452
# Generation 1680/5000. Best fitness: 0.000482392667631452
# Generation 1690/5000. Best fitness: 0.000482392667631452
# Generation 1700/5000. Best fitness: 0.000482392667631452
# Generation 1710/5000. Best fitness: 0.000482392667631452
# Generation 1720/5000. Best fitness: 0.000482392667631452
# Generation 1730/5000. Best fitness: 0.000482392667631452
# Generation 1740/5000. Best fitness: 0.000482392667631452
# Generation 1750/5000. Best fitness: 0.000482392667631452
# Generation 1760/5000. Best fitness: 0.000482392667631452
# Generation 1770/5000. Best fitness: 0.000482392667631452
# Generation 1780/5000. Best fitness: 0.000482392667631452
# Generation 1790/5000. Best fitness: 0.000482392667631452
# Generation 1800/5000. Best fitness: 0.000482392667631452
# Generation 1810/5000. Best fitness: 0.000482392667631452
# Generation 1820/5000. Best fitness: 0.000482392667631452
# Generation 1830/5000. Best fitness: 0.000482392667631452
# Generation 1840/5000. Best fitness: 0.000482392667631452
# Generation 1850/5000. Best fitness: 0.000482392667631452
# Generation 1860/5000. Best fitness: 0.000482392667631452
# Generation 1870/5000. Best fitness: 0.000482392667631452
# Generation 1880/5000. Best fitness: 0.000482392667631452
# Generation 1890/5000. Best fitness: 0.000482392667631452
# Generation 1900/5000. Best fitness: 0.000482392667631452
# Generation 1910/5000. Best fitness: 0.000482392667631452
# Generation 1920/5000. Best fitness: 0.000482392667631452
# Generation 1930/5000. Best fitness: 0.000482392667631452
# Generation 1940/5000. Best fitness: 0.000482392667631452
# Generation 1950/5000. Best fitness: 0.000482392667631452
# Generation 1960/5000. Best fitness: 0.000482392667631452
# Generation 1970/5000. Best fitness: 0.000482392667631452
# Generation 1980/5000. Best fitness: 0.000482392667631452
# Generation 1990/5000. Best fitness: 0.000482392667631452
# Generation 2000/5000. Best fitness: 0.000482392667631452
# Generation 2010/5000. Best fitness: 0.000482392667631452
# Generation 2020/5000. Best fitness: 0.000482392667631452
# Generation 2030/5000. Best fitness: 0.000482392667631452
# Generation 2040/5000. Best fitness: 0.000482392667631452
# Generation 2050/5000. Best fitness: 0.000482392667631452
# Generation 2060/5000. Best fitness: 0.000482392667631452
# Generation 2070/5000. Best fitness: 0.000482392667631452
# Generation 2080/5000. Best fitness: 0.000482392667631452
# Generation 2090/5000. Best fitness: 0.000482392667631452
# Generation 2100/5000. Best fitness: 0.000482392667631452
# Generation 2110/5000. Best fitness: 0.000482392667631452
# Generation 2120/5000. Best fitness: 0.000482392667631452
# Generation 2130/5000. Best fitness: 0.000482392667631452
# Generation 2140/5000. Best fitness: 0.000482392667631452
# Generation 2150/5000. Best fitness: 0.000482392667631452
# Generation 2160/5000. Best fitness: 0.000482392667631452
# Generation 2170/5000. Best fitness: 0.000482392667631452
# Generation 2180/5000. Best fitness: 0.000482392667631452
# Generation 2190/5000. Best fitness: 0.000482392667631452
# Generation 2200/5000. Best fitness: 0.000482392667631452
# Generation 2210/5000. Best fitness: 0.000482392667631452
# Generation 2220/5000. Best fitness: 0.000482392667631452
# Generation 2230/5000. Best fitness: 0.000482392667631452
# Generation 2240/5000. Best fitness: 0.000482392667631452
# Generation 2250/5000. Best fitness: 0.000482392667631452
# Generation 2260/5000. Best fitness: 0.000482392667631452
# Generation 2270/5000. Best fitness: 0.000482392667631452
# Generation 2280/5000. Best fitness: 0.000482392667631452
# Generation 2290/5000. Best fitness: 0.000482392667631452
# Generation 2300/5000. Best fitness: 0.000482392667631452
# Generation 2310/5000. Best fitness: 0.000482392667631452
# Generation 2320/5000. Best fitness: 0.000482392667631452
# Generation 2330/5000. Best fitness: 0.000482392667631452
# Generation 2340/5000. Best fitness: 0.000482392667631452
# Generation 2350/5000. Best fitness: 0.000482392667631452
# Generation 2360/5000. Best fitness: 0.000482392667631452
# Generation 2370/5000. Best fitness: 0.000482392667631452
# Generation 2380/5000. Best fitness: 0.000482392667631452
# Generation 2390/5000. Best fitness: 0.000482392667631452
# Generation 2400/5000. Best fitness: 0.000482392667631452
# Generation 2410/5000. Best fitness: 0.000482392667631452
# Generation 2420/5000. Best fitness: 0.000482392667631452
# Generation 2430/5000. Best fitness: 0.000482392667631452
# Generation 2440/5000. Best fitness: 0.000482392667631452
# Generation 2450/5000. Best fitness: 0.000482392667631452
# Generation 2460/5000. Best fitness: 0.000482392667631452
# Generation 2470/5000. Best fitness: 0.000482392667631452
# Generation 2480/5000. Best fitness: 0.000482392667631452
# Generation 2490/5000. Best fitness: 0.000482392667631452
# Generation 2500/5000. Best fitness: 0.000482392667631452
# Generation 2510/5000. Best fitness: 0.000482392667631452
# Generation 2520/5000. Best fitness: 0.000482392667631452
# Generation 2530/5000. Best fitness: 0.000482392667631452
# Generation 2540/5000. Best fitness: 0.000482392667631452
# Generation 2550/5000. Best fitness: 0.000482392667631452
# Generation 2560/5000. Best fitness: 0.000482392667631452
# Generation 2570/5000. Best fitness: 0.000482392667631452
# Generation 2580/5000. Best fitness: 0.000482392667631452
# Generation 2590/5000. Best fitness: 0.000482392667631452
# Generation 2600/5000. Best fitness: 0.000482392667631452
# Generation 2610/5000. Best fitness: 0.000482392667631452
# Generation 2620/5000. Best fitness: 0.000482392667631452
# Generation 2630/5000. Best fitness: 0.000482392667631452
# Generation 2640/5000. Best fitness: 0.000482392667631452
# Generation 2650/5000. Best fitness: 0.000482392667631452
# Generation 2660/5000. Best fitness: 0.000482392667631452
# Generation 2670/5000. Best fitness: 0.000482392667631452
# Generation 2680/5000. Best fitness: 0.000482392667631452
# Generation 2690/5000. Best fitness: 0.000482392667631452
# Generation 2700/5000. Best fitness: 0.000482392667631452
# Generation 2710/5000. Best fitness: 0.000482392667631452
# Generation 2720/5000. Best fitness: 0.000482392667631452
# Generation 2730/5000. Best fitness: 0.000482392667631452
# Generation 2740/5000. Best fitness: 0.000482392667631452
# Generation 2750/5000. Best fitness: 0.000482392667631452
# Generation 2760/5000. Best fitness: 0.000482392667631452
# Generation 2770/5000. Best fitness: 0.000482392667631452
# Generation 2780/5000. Best fitness: 0.000482392667631452
# Generation 2790/5000. Best fitness: 0.000482392667631452
# Generation 2800/5000. Best fitness: 0.000482392667631452
# Generation 2810/5000. Best fitness: 0.000482392667631452
# Generation 2820/5000. Best fitness: 0.000482392667631452
# Generation 2830/5000. Best fitness: 0.000482392667631452
# Generation 2840/5000. Best fitness: 0.000482392667631452
# Generation 2850/5000. Best fitness: 0.000482392667631452
# Generation 2860/5000. Best fitness: 0.000482392667631452
# Generation 2870/5000. Best fitness: 0.000482392667631452
# Generation 2880/5000. Best fitness: 0.000482392667631452
# Generation 2890/5000. Best fitness: 0.000482392667631452
# Generation 2900/5000. Best fitness: 0.000482392667631452
# Generation 2910/5000. Best fitness: 0.000482392667631452
# Generation 2920/5000. Best fitness: 0.000482392667631452
# Generation 2930/5000. Best fitness: 0.000482392667631452
# Generation 2940/5000. Best fitness: 0.000482392667631452
# Generation 2950/5000. Best fitness: 0.000482392667631452
# Generation 2960/5000. Best fitness: 0.000482392667631452
# Generation 2970/5000. Best fitness: 0.000482392667631452
# Generation 2980/5000. Best fitness: 0.000482392667631452
# Generation 2990/5000. Best fitness: 0.000482392667631452
# Generation 3000/5000. Best fitness: 0.000482392667631452
# Generation 3010/5000. Best fitness: 0.000482392667631452
# Generation 3020/5000. Best fitness: 0.000482392667631452
# Generation 3030/5000. Best fitness: 0.000482392667631452
# Generation 3040/5000. Best fitness: 0.000482392667631452
# Generation 3050/5000. Best fitness: 0.000482392667631452
# Generation 3060/5000. Best fitness: 0.000482392667631452
# Generation 3070/5000. Best fitness: 0.000482392667631452
# Generation 3080/5000. Best fitness: 0.000482392667631452
# Generation 3090/5000. Best fitness: 0.000482392667631452
# Generation 3100/5000. Best fitness: 0.000482392667631452
# Generation 3110/5000. Best fitness: 0.000482392667631452
# Generation 3120/5000. Best fitness: 0.000482392667631452
# Generation 3130/5000. Best fitness: 0.000482392667631452
# Generation 3140/5000. Best fitness: 0.000482392667631452
# Generation 3150/5000. Best fitness: 0.000482392667631452
# Generation 3160/5000. Best fitness: 0.000482392667631452
# Generation 3170/5000. Best fitness: 0.000482392667631452
# Generation 3180/5000. Best fitness: 0.000482392667631452
# Generation 3190/5000. Best fitness: 0.000482392667631452
# Generation 3200/5000. Best fitness: 0.000482392667631452
# Generation 3210/5000. Best fitness: 0.000482392667631452
# Generation 3220/5000. Best fitness: 0.000482392667631452
# Generation 3230/5000. Best fitness: 0.000482392667631452
# Generation 3240/5000. Best fitness: 0.000482392667631452
# Generation 3250/5000. Best fitness: 0.000482392667631452
# Generation 3260/5000. Best fitness: 0.000482392667631452
# Generation 3270/5000. Best fitness: 0.000482392667631452
# Generation 3280/5000. Best fitness: 0.000482392667631452
# Generation 3290/5000. Best fitness: 0.000482392667631452
# Generation 3300/5000. Best fitness: 0.000482392667631452
# Generation 3310/5000. Best fitness: 0.000482392667631452
# Generation 3320/5000. Best fitness: 0.000482392667631452
# Generation 3330/5000. Best fitness: 0.000482392667631452
# Generation 3340/5000. Best fitness: 0.000482392667631452
# Generation 3350/5000. Best fitness: 0.000482392667631452
# Generation 3360/5000. Best fitness: 0.000482392667631452
# Generation 3370/5000. Best fitness: 0.000482392667631452
# Generation 3380/5000. Best fitness: 0.000482392667631452
# Generation 3390/5000. Best fitness: 0.000482392667631452
# Generation 3400/5000. Best fitness: 0.000482392667631452
# Generation 3410/5000. Best fitness: 0.000482392667631452
# Generation 3420/5000. Best fitness: 0.000482392667631452
# Generation 3430/5000. Best fitness: 0.000482392667631452
# Generation 3440/5000. Best fitness: 0.000482392667631452
# Generation 3450/5000. Best fitness: 0.000482392667631452
# Generation 3460/5000. Best fitness: 0.000482392667631452
# Generation 3470/5000. Best fitness: 0.000482392667631452
# Generation 3480/5000. Best fitness: 0.000482392667631452
# Generation 3490/5000. Best fitness: 0.000482392667631452
# Generation 3500/5000. Best fitness: 0.000482392667631452
# Generation 3510/5000. Best fitness: 0.000482392667631452
# Generation 3520/5000. Best fitness: 0.000482392667631452
# Generation 3530/5000. Best fitness: 0.000482392667631452
# Generation 3540/5000. Best fitness: 0.000482392667631452
# Generation 3550/5000. Best fitness: 0.000482392667631452
# Generation 3560/5000. Best fitness: 0.000482392667631452
# Generation 3570/5000. Best fitness: 0.000482392667631452
# Generation 3580/5000. Best fitness: 0.000482392667631452
# Generation 3590/5000. Best fitness: 0.000482392667631452
# Generation 3600/5000. Best fitness: 0.000482392667631452
# Generation 3610/5000. Best fitness: 0.000482392667631452
# Generation 3620/5000. Best fitness: 0.000482392667631452
# Generation 3630/5000. Best fitness: 0.000482392667631452
# Generation 3640/5000. Best fitness: 0.000482392667631452
# Generation 3650/5000. Best fitness: 0.000482392667631452
# Generation 3660/5000. Best fitness: 0.000482392667631452
# Generation 3670/5000. Best fitness: 0.000482392667631452
# Generation 3680/5000. Best fitness: 0.000482392667631452
# Generation 3690/5000. Best fitness: 0.000482392667631452
# Generation 3700/5000. Best fitness: 0.000482392667631452
# Generation 3710/5000. Best fitness: 0.000482392667631452
# Generation 3720/5000. Best fitness: 0.000482392667631452
# Generation 3730/5000. Best fitness: 0.000482392667631452
# Generation 3740/5000. Best fitness: 0.000482392667631452
# Generation 3750/5000. Best fitness: 0.000482392667631452
# Generation 3760/5000. Best fitness: 0.000482392667631452
# Generation 3770/5000. Best fitness: 0.000482392667631452
# Generation 3780/5000. Best fitness: 0.000482392667631452
# Generation 3790/5000. Best fitness: 0.000482392667631452
# Generation 3800/5000. Best fitness: 0.000482392667631452
# Generation 3810/5000. Best fitness: 0.000482392667631452
# Generation 3820/5000. Best fitness: 0.000482392667631452
# Generation 3830/5000. Best fitness: 0.000482392667631452
# Generation 3840/5000. Best fitness: 0.000482392667631452
# Generation 3850/5000. Best fitness: 0.000482392667631452
# Generation 3860/5000. Best fitness: 0.000482392667631452
# Generation 3870/5000. Best fitness: 0.000482392667631452
# Generation 3880/5000. Best fitness: 0.000482392667631452
# Generation 3890/5000. Best fitness: 0.000482392667631452
# Generation 3900/5000. Best fitness: 0.000482392667631452
# Generation 3910/5000. Best fitness: 0.000482392667631452
# Generation 3920/5000. Best fitness: 0.000482392667631452
# Generation 3930/5000. Best fitness: 0.000482392667631452
# Generation 3940/5000. Best fitness: 0.000482392667631452
# Generation 3950/5000. Best fitness: 0.000482392667631452
# Generation 3960/5000. Best fitness: 0.000482392667631452
# Generation 3970/5000. Best fitness: 0.000482392667631452
# Generation 3980/5000. Best fitness: 0.000482392667631452
# Generation 3990/5000. Best fitness: 0.000482392667631452
# Generation 4000/5000. Best fitness: 0.000482392667631452
# Generation 4010/5000. Best fitness: 0.000482392667631452
# Generation 4020/5000. Best fitness: 0.000482392667631452
# Generation 4030/5000. Best fitness: 0.000482392667631452
# Generation 4040/5000. Best fitness: 0.000482392667631452
# Generation 4050/5000. Best fitness: 0.000482392667631452
# Generation 4060/5000. Best fitness: 0.000482392667631452
# Generation 4070/5000. Best fitness: 0.000482392667631452
# Generation 4080/5000. Best fitness: 0.000482392667631452
# Generation 4090/5000. Best fitness: 0.000482392667631452
# Generation 4100/5000. Best fitness: 0.000482392667631452
# Generation 4110/5000. Best fitness: 0.000482392667631452
# Generation 4120/5000. Best fitness: 0.000482392667631452
# Generation 4130/5000. Best fitness: 0.000482392667631452
# Generation 4140/5000. Best fitness: 0.000482392667631452
# Generation 4150/5000. Best fitness: 0.000482392667631452
# Generation 4160/5000. Best fitness: 0.000482392667631452
# Generation 4170/5000. Best fitness: 0.000482392667631452
# Generation 4180/5000. Best fitness: 0.000482392667631452
# Generation 4190/5000. Best fitness: 0.000482392667631452
# Generation 4200/5000. Best fitness: 0.000482392667631452
# Generation 4210/5000. Best fitness: 0.000482392667631452
# Generation 4220/5000. Best fitness: 0.000482392667631452
# Generation 4230/5000. Best fitness: 0.000482392667631452
# Generation 4240/5000. Best fitness: 0.000482392667631452
# Generation 4250/5000. Best fitness: 0.000482392667631452
# Generation 4260/5000. Best fitness: 0.000482392667631452
# Generation 4270/5000. Best fitness: 0.000482392667631452
# Generation 4280/5000. Best fitness: 0.000482392667631452
# Generation 4290/5000. Best fitness: 0.000482392667631452
# Generation 4300/5000. Best fitness: 0.000482392667631452
# Generation 4310/5000. Best fitness: 0.000482392667631452
# Generation 4320/5000. Best fitness: 0.000482392667631452
# Generation 4330/5000. Best fitness: 0.000482392667631452
# Generation 4340/5000. Best fitness: 0.000482392667631452
# Generation 4350/5000. Best fitness: 0.000482392667631452
# Generation 4360/5000. Best fitness: 0.000482392667631452
# Generation 4370/5000. Best fitness: 0.000482392667631452
# Generation 4380/5000. Best fitness: 0.000482392667631452
# Generation 4390/5000. Best fitness: 0.000482392667631452
# Generation 4400/5000. Best fitness: 0.000482392667631452
# Generation 4410/5000. Best fitness: 0.000482392667631452
# Generation 4420/5000. Best fitness: 0.000482392667631452
# Generation 4430/5000. Best fitness: 0.000482392667631452
# Generation 4440/5000. Best fitness: 0.000482392667631452
# Generation 4450/5000. Best fitness: 0.000482392667631452
# Generation 4460/5000. Best fitness: 0.000482392667631452
# Generation 4470/5000. Best fitness: 0.000482392667631452
# Generation 4480/5000. Best fitness: 0.000482392667631452
# Generation 4490/5000. Best fitness: 0.000482392667631452
# Generation 4500/5000. Best fitness: 0.000482392667631452
# Generation 4510/5000. Best fitness: 0.000482392667631452
# Generation 4520/5000. Best fitness: 0.000482392667631452
# Generation 4530/5000. Best fitness: 0.000482392667631452
# Generation 4540/5000. Best fitness: 0.000482392667631452
# Generation 4550/5000. Best fitness: 0.000482392667631452
# Generation 4560/5000. Best fitness: 0.000482392667631452
# Generation 4570/5000. Best fitness: 0.000482392667631452
# Generation 4580/5000. Best fitness: 0.000482392667631452
# Generation 4590/5000. Best fitness: 0.000482392667631452
# Generation 4600/5000. Best fitness: 0.000482392667631452
# Generation 4610/5000. Best fitness: 0.000482392667631452
# Generation 4620/5000. Best fitness: 0.000482392667631452
# Generation 4630/5000. Best fitness: 0.000482392667631452
# Generation 4640/5000. Best fitness: 0.000482392667631452
# Generation 4650/5000. Best fitness: 0.000482392667631452
# Generation 4660/5000. Best fitness: 0.000482392667631452
# Generation 4670/5000. Best fitness: 0.000482392667631452
# Generation 4680/5000. Best fitness: 0.000482392667631452
# Generation 4690/5000. Best fitness: 0.000482392667631452
# Generation 4700/5000. Best fitness: 0.000482392667631452
# Generation 4710/5000. Best fitness: 0.000482392667631452
# Generation 4720/5000. Best fitness: 0.000482392667631452
# Generation 4730/5000. Best fitness: 0.000482392667631452
# Generation 4740/5000. Best fitness: 0.000482392667631452
# Generation 4750/5000. Best fitness: 0.000482392667631452
# Generation 4760/5000. Best fitness: 0.000482392667631452
# Generation 4770/5000. Best fitness: 0.000482392667631452
# Generation 4780/5000. Best fitness: 0.000482392667631452
# Generation 4790/5000. Best fitness: 0.000482392667631452
# Generation 4800/5000. Best fitness: 0.000482392667631452
# Generation 4810/5000. Best fitness: 0.000482392667631452
# Generation 4820/5000. Best fitness: 0.000482392667631452
# Generation 4830/5000. Best fitness: 0.000482392667631452
# Generation 4840/5000. Best fitness: 0.000482392667631452
# Generation 4850/5000. Best fitness: 0.000482392667631452
# Generation 4860/5000. Best fitness: 0.000482392667631452
# Generation 4870/5000. Best fitness: 0.000482392667631452
# Generation 4880/5000. Best fitness: 0.000482392667631452
# Generation 4890/5000. Best fitness: 0.000482392667631452
# Generation 4900/5000. Best fitness: 0.000482392667631452
# Generation 4910/5000. Best fitness: 0.000482392667631452
# Generation 4920/5000. Best fitness: 0.000482392667631452
# Generation 4930/5000. Best fitness: 0.000482392667631452
# Generation 4940/5000. Best fitness: 0.000482392667631452
# Generation 4950/5000. Best fitness: 0.000482392667631452
# Generation 4960/5000. Best fitness: 0.000482392667631452
# Generation 4970/5000. Best fitness: 0.000482392667631452
# Generation 4980/5000. Best fitness: 0.000482392667631452
# Generation 4990/5000. Best fitness: 0.000482392667631452
# Generation 5000/5000. Best fitness: 0.000482392667631452
# Best fitness score is equal:0.000482392667631452 and makespan: 2073.0

# %%
best_chromosome
# Out:
# [Operation(task_id=9, op_id=10, resource=2, duration=25),
#  Operation(task_id=29, op_id=8, resource=8, duration=33),
#  Operation(task_id=46, op_id=5, resource=10, duration=29),
#  Operation(task_id=38, op_id=5, resource=1, duration=18),
#  Operation(task_id=16, op_id=6, resource=9, duration=21),
#  Operation(task_id=5, op_id=5, resource=1, duration=29),
#  Operation(task_id=17, op_id=7, resource=4, duration=14),
#  Operation(task_id=2, op_id=9, resource=9, duration=12),
#  Operation(task_id=8, op_id=5, resource=8, duration=48),
#  Operation(task_id=25, op_id=2, resource=7, duration=19),
#  Operation(task_id=38, op_id=8, resource=10, duration=24),
#  Operation(task_id=38, op_id=6, resource=1, duration=22),
#  Operation(task_id=18, op_id=8, resource=5, duration=45),
#  Operation(task_id=22, op_id=3, resource=7, duration=33),
#  Operation(task_id=5, op_id=7, resource=9, duration=35),
#  Operation(task_id=12, op_id=5, resource=8, duration=40),
#  Operation(task_id=36, op_id=2, resource=4, duration=24),
#  Operation(task_id=19, op_id=9, resource=7, duration=28),
#  Operation(task_id=22, op_id=1, resource=5, duration=35),
#  Operation(task_id=25, op_id=4, resource=1, duration=27),
#  Operation(task_id=47, op_id=10, resource=4, duration=33),
#  Operation(task_id=16, op_id=8, resource=2, duration=37),
#  Operation(task_id=15, op_id=3, resource=3, duration=21),
#  Operation(task_id=11, op_id=3, resource=7, duration=23),
#  Operation(task_id=16, op_id=9, resource=9, duration=45),
#  Operation(task_id=35, op_id=0, resource=6, duration=31),
#  Operation(task_id=8, op_id=7, resource=8, duration=23),
#  Operation(task_id=15, op_id=8, resource=3, duration=10),
#  Operation(task_id=39, op_id=3, resource=1, duration=10),
#  Operation(task_id=28, op_id=1, resource=3, duration=50),
#  Operation(task_id=39, op_id=7, resource=10, duration=13),
#  Operation(task_id=37, op_id=9, resource=6, duration=26),
#  Operation(task_id=44, op_id=8, resource=3, duration=50),
#  Operation(task_id=9, op_id=1, resource=3, duration=21),
#  Operation(task_id=35, op_id=9, resource=4, duration=30),
#  Operation(task_id=21, op_id=8, resource=2, duration=50),
#  Operation(task_id=36, op_id=1, resource=5, duration=38),
#  Operation(task_id=3, op_id=6, resource=8, duration=50),
#  Operation(task_id=47, op_id=4, resource=4, duration=26),
#  Operation(task_id=49, op_id=10, resource=1, duration=19),
#  Operation(task_id=21, op_id=5, resource=5, duration=20),
#  Operation(task_id=35, op_id=6, resource=10, duration=46),
#  Operation(task_id=40, op_id=9, resource=7, duration=47),
#  Operation(task_id=36, op_id=3, resource=4, duration=46),
#  Operation(task_id=31, op_id=2, resource=3, duration=27),
#  Operation(task_id=30, op_id=5, resource=6, duration=31),
#  Operation(task_id=34, op_id=2, resource=1, duration=29),
#  Operation(task_id=18, op_id=7, resource=6, duration=22),
#  Operation(task_id=46, op_id=4, resource=7, duration=50),
#  Operation(task_id=4, op_id=7, resource=1, duration=10),
#  Operation(task_id=46, op_id=2, resource=8, duration=22),
#  Operation(task_id=8, op_id=10, resource=5, duration=15),
#  Operation(task_id=11, op_id=6, resource=1, duration=14),
#  Operation(task_id=18, op_id=10, resource=2, duration=13),
#  Operation(task_id=10, op_id=3, resource=9, duration=23),
#  Operation(task_id=12, op_id=9, resource=2, duration=19),
#  Operation(task_id=49, op_id=3, resource=10, duration=13),
#  Operation(task_id=1, op_id=2, resource=1, duration=47),
#  Operation(task_id=48, op_id=5, resource=3, duration=38),
#  Operation(task_id=22, op_id=5, resource=3, duration=22),
#  Operation(task_id=19, op_id=5, resource=3, duration=10),
#  Operation(task_id=35, op_id=4, resource=5, duration=17),
#  Operation(task_id=13, op_id=9, resource=8, duration=11),
#  Operation(task_id=26, op_id=6, resource=1, duration=21),
#  Operation(task_id=39, op_id=9, resource=5, duration=28),
#  Operation(task_id=24, op_id=5, resource=2, duration=16),
#  Operation(task_id=6, op_id=9, resource=7, duration=12),
#  Operation(task_id=33, op_id=8, resource=10, duration=38),
#  Operation(task_id=38, op_id=7, resource=3, duration=31),
#  Operation(task_id=41, op_id=5, resource=7, duration=31),
#  Operation(task_id=44, op_id=9, resource=6, duration=48),
#  Operation(task_id=37, op_id=4, resource=8, duration=22),
#  Operation(task_id=39, op_id=0, resource=10, duration=43),
#  Operation(task_id=42, op_id=8, resource=4, duration=11),
#  Operation(task_id=7, op_id=6, resource=3, duration=47),
#  Operation(task_id=2, op_id=10, resource=7, duration=13),
#  Operation(task_id=5, op_id=3, resource=2, duration=20),
#  Operation(task_id=6, op_id=8, resource=5, duration=15),
#  Operation(task_id=30, op_id=7, resource=7, duration=47),
#  Operation(task_id=50, op_id=5, resource=2, duration=33),
#  Operation(task_id=12, op_id=1, resource=3, duration=12),
#  Operation(task_id=41, op_id=3, resource=8, duration=18),
#  Operation(task_id=45, op_id=0, resource=1, duration=47),
#  Operation(task_id=6, op_id=6, resource=7, duration=30),
#  Operation(task_id=39, op_id=6, resource=9, duration=37),
#  Operation(task_id=25, op_id=5, resource=6, duration=22),
#  Operation(task_id=49, op_id=7, resource=4, duration=18),
#  Operation(task_id=40, op_id=5, resource=1, duration=17),
#  Operation(task_id=45, op_id=8, resource=7, duration=43),
#  Operation(task_id=9, op_id=6, resource=3, duration=38),
#  Operation(task_id=44, op_id=1, resource=5, duration=47),
#  Operation(task_id=25, op_id=3, resource=9, duration=43),
#  Operation(task_id=48, op_id=9, resource=6, duration=20),
#  Operation(task_id=15, op_id=5, resource=3, duration=20),
#  Operation(task_id=21, op_id=10, resource=4, duration=14),
#  Operation(task_id=28, op_id=6, resource=5, duration=16),
#  Operation(task_id=45, op_id=2, resource=7, duration=13),
#  Operation(task_id=48, op_id=1, resource=7, duration=22),
#  Operation(task_id=6, op_id=0, resource=6, duration=33),
#  Operation(task_id=43, op_id=4, resource=3, duration=20),
#  Operation(task_id=10, op_id=4, resource=10, duration=31),
#  Operation(task_id=40, op_id=6, resource=1, duration=42),
#  Operation(task_id=10, op_id=9, resource=10, duration=50),
#  Operation(task_id=2, op_id=5, resource=8, duration=33),
#  Operation(task_id=38, op_id=9, resource=2, duration=40),
#  Operation(task_id=40, op_id=3, resource=2, duration=26),
#  Operation(task_id=18, op_id=9, resource=7, duration=22),
#  Operation(task_id=50, op_id=1, resource=2, duration=46),
#  Operation(task_id=39, op_id=4, resource=5, duration=32),
#  Operation(task_id=3, op_id=10, resource=1, duration=26),
#  Operation(task_id=49, op_id=8, resource=6, duration=40),
#  Operation(task_id=24, op_id=0, resource=1, duration=50),
#  Operation(task_id=1, op_id=5, resource=3, duration=19),
#  Operation(task_id=10, op_id=6, resource=7, duration=14),
#  Operation(task_id=5, op_id=6, resource=4, duration=21),
#  Operation(task_id=23, op_id=4, resource=7, duration=37),
#  Operation(task_id=26, op_id=4, resource=4, duration=40),
#  Operation(task_id=5, op_id=2, resource=6, duration=30),
#  Operation(task_id=41, op_id=10, resource=10, duration=48),
#  Operation(task_id=13, op_id=2, resource=9, duration=13),
#  Operation(task_id=37, op_id=5, resource=3, duration=11),
#  Operation(task_id=25, op_id=1, resource=1, duration=28),
#  Operation(task_id=45, op_id=9, resource=6, duration=36),
#  Operation(task_id=43, op_id=10, resource=2, duration=41),
#  Operation(task_id=32, op_id=10, resource=6, duration=19),
#  Operation(task_id=34, op_id=9, resource=8, duration=10),
#  Operation(task_id=4, op_id=3, resource=7, duration=18),
#  Operation(task_id=46, op_id=7, resource=10, duration=11),
#  Operation(task_id=21, op_id=7, resource=4, duration=26),
#  Operation(task_id=3, op_id=1, resource=4, duration=28),
#  Operation(task_id=32, op_id=0, resource=3, duration=31),
#  Operation(task_id=3, op_id=5, resource=10, duration=31),
#  Operation(task_id=19, op_id=0, resource=4, duration=47),
#  Operation(task_id=34, op_id=7, resource=7, duration=24),
#  Operation(task_id=25, op_id=8, resource=10, duration=36),
#  Operation(task_id=11, op_id=9, resource=9, duration=50),
#  Operation(task_id=49, op_id=2, resource=6, duration=31),
#  Operation(task_id=5, op_id=0, resource=9, duration=14),
#  Operation(task_id=13, op_id=8, resource=8, duration=15),
#  Operation(task_id=23, op_id=2, resource=1, duration=42),
#  Operation(task_id=22, op_id=6, resource=1, duration=16),
#  Operation(task_id=16, op_id=5, resource=3, duration=21),
#  Operation(task_id=38, op_id=10, resource=2, duration=46),
#  Operation(task_id=43, op_id=1, resource=8, duration=32),
#  Operation(task_id=20, op_id=10, resource=6, duration=34),
#  Operation(task_id=43, op_id=2, resource=7, duration=37),
#  Operation(task_id=22, op_id=9, resource=1, duration=16),
#  Operation(task_id=16, op_id=3, resource=3, duration=11),
#  Operation(task_id=27, op_id=2, resource=2, duration=30),
#  Operation(task_id=18, op_id=1, resource=1, duration=31),
#  Operation(task_id=48, op_id=8, resource=4, duration=48),
#  Operation(task_id=7, op_id=10, resource=4, duration=17),
#  Operation(task_id=1, op_id=3, resource=9, duration=30),
#  Operation(task_id=26, op_id=0, resource=5, duration=37),
#  Operation(task_id=30, op_id=6, resource=10, duration=10),
#  Operation(task_id=9, op_id=5, resource=3, duration=31),
#  Operation(task_id=31, op_id=1, resource=1, duration=29),
#  Operation(task_id=14, op_id=4, resource=7, duration=28),
#  Operation(task_id=29, op_id=1, resource=2, duration=18),
#  Operation(task_id=43, op_id=8, resource=3, duration=10),
#  Operation(task_id=17, op_id=10, resource=8, duration=49),
#  Operation(task_id=8, op_id=4, resource=10, duration=21),
#  Operation(task_id=16, op_id=0, resource=3, duration=39),
#  Operation(task_id=41, op_id=0, resource=9, duration=15),
#  Operation(task_id=26, op_id=5, resource=8, duration=27),
#  Operation(task_id=23, op_id=3, resource=9, duration=25),
#  Operation(task_id=39, op_id=2, resource=10, duration=29),
#  Operation(task_id=15, op_id=1, resource=3, duration=33),
#  Operation(task_id=2, op_id=4, resource=6, duration=27),
#  Operation(task_id=3, op_id=3, resource=5, duration=32),
#  Operation(task_id=14, op_id=10, resource=1, duration=13),
#  Operation(task_id=45, op_id=1, resource=7, duration=39),
#  Operation(task_id=45, op_id=5, resource=3, duration=43),
#  Operation(task_id=27, op_id=0, resource=1, duration=11),
#  Operation(task_id=46, op_id=6, resource=10, duration=33),
#  Operation(task_id=41, op_id=2, resource=3, duration=29),
#  Operation(task_id=21, op_id=4, resource=2, duration=16),
#  Operation(task_id=18, op_id=6, resource=4, duration=13),
#  Operation(task_id=50, op_id=9, resource=7, duration=43),
#  Operation(task_id=49, op_id=9, resource=3, duration=40),
#  Operation(task_id=25, op_id=7, resource=3, duration=22),
#  Operation(task_id=48, op_id=6, resource=6, duration=24),
#  Operation(task_id=37, op_id=0, resource=6, duration=25),
#  Operation(task_id=21, op_id=0, resource=8, duration=21),
#  Operation(task_id=17, op_id=3, resource=8, duration=19),
#  Operation(task_id=14, op_id=3, resource=2, duration=36),
#  Operation(task_id=6, op_id=7, resource=5, duration=34),
#  Operation(task_id=28, op_id=5, resource=1, duration=23),
#  Operation(task_id=47, op_id=0, resource=9, duration=24),
#  Operation(task_id=44, op_id=7, resource=2, duration=49),
#  Operation(task_id=7, op_id=7, resource=7, duration=43),
#  Operation(task_id=33, op_id=9, resource=1, duration=17),
#  Operation(task_id=28, op_id=2, resource=4, duration=12),
#  Operation(task_id=13, op_id=4, resource=2, duration=47),
#  Operation(task_id=9, op_id=0, resource=4, duration=42),
#  Operation(task_id=40, op_id=7, resource=2, duration=33),
#  Operation(task_id=1, op_id=4, resource=5, duration=21),
#  Operation(task_id=31, op_id=0, resource=10, duration=28),
#  Operation(task_id=45, op_id=4, resource=3, duration=16),
#  Operation(task_id=11, op_id=4, resource=4, duration=10),
#  Operation(task_id=23, op_id=0, resource=3, duration=16),
#  Operation(task_id=12, op_id=2, resource=10, duration=36),
#  Operation(task_id=40, op_id=0, resource=3, duration=11),
#  Operation(task_id=1, op_id=0, resource=9, duration=22),
#  Operation(task_id=31, op_id=8, resource=10, duration=12),
#  Operation(task_id=8, op_id=8, resource=4, duration=40),
#  Operation(task_id=32, op_id=5, resource=6, duration=41),
#  Operation(task_id=4, op_id=0, resource=8, duration=40),
#  Operation(task_id=37, op_id=10, resource=1, duration=12),
#  Operation(task_id=15, op_id=6, resource=7, duration=26),
#  Operation(task_id=44, op_id=6, resource=4, duration=11),
#  Operation(task_id=47, op_id=3, resource=7, duration=22),
#  Operation(task_id=18, op_id=4, resource=1, duration=47),
#  Operation(task_id=48, op_id=7, resource=8, duration=20),
#  Operation(task_id=30, op_id=3, resource=10, duration=24),
#  Operation(task_id=6, op_id=5, resource=5, duration=26),
#  Operation(task_id=41, op_id=7, resource=7, duration=41),
#  Operation(task_id=19, op_id=8, resource=8, duration=22),
#  Operation(task_id=49, op_id=5, resource=10, duration=21),
#  Operation(task_id=17, op_id=5, resource=9, duration=10),
#  Operation(task_id=7, op_id=1, resource=4, duration=17),
#  Operation(task_id=42, op_id=10, resource=6, duration=39),
#  Operation(task_id=4, op_id=2, resource=5, duration=47),
#  Operation(task_id=12, op_id=8, resource=10, duration=31),
#  Operation(task_id=38, op_id=0, resource=3, duration=28),
#  Operation(task_id=14, op_id=1, resource=2, duration=20),
#  Operation(task_id=44, op_id=4, resource=7, duration=19),
#  Operation(task_id=42, op_id=4, resource=1, duration=31),
#  Operation(task_id=44, op_id=3, resource=1, duration=45),
#  Operation(task_id=5, op_id=1, resource=7, duration=45),
#  Operation(task_id=31, op_id=4, resource=2, duration=23),
#  Operation(task_id=42, op_id=2, resource=4, duration=42),
#  Operation(task_id=28, op_id=9, resource=1, duration=38),
#  Operation(task_id=31, op_id=5, resource=5, duration=10),
#  Operation(task_id=26, op_id=2, resource=9, duration=25),
#  Operation(task_id=9, op_id=9, resource=7, duration=47),
#  Operation(task_id=33, op_id=2, resource=3, duration=11),
#  Operation(task_id=22, op_id=7, resource=9, duration=23),
#  Operation(task_id=48, op_id=4, resource=4, duration=19),
#  Operation(task_id=15, op_id=4, resource=9, duration=12),
#  Operation(task_id=18, op_id=5, resource=8, duration=11),
#  Operation(task_id=30, op_id=9, resource=9, duration=19),
#  Operation(task_id=12, op_id=0, resource=5, duration=41),
#  Operation(task_id=16, op_id=10, resource=1, duration=29),
#  Operation(task_id=5, op_id=10, resource=7, duration=36),
#  Operation(task_id=39, op_id=8, resource=10, duration=38),
#  Operation(task_id=32, op_id=6, resource=8, duration=35),
#  Operation(task_id=41, op_id=8, resource=1, duration=32),
#  Operation(task_id=34, op_id=5, resource=8, duration=26),
#  Operation(task_id=33, op_id=10, resource=7, duration=10),
#  Operation(task_id=2, op_id=2, resource=7, duration=23),
#  Operation(task_id=36, op_id=4, resource=2, duration=23),
#  Operation(task_id=35, op_id=3, resource=4, duration=47),
#  Operation(task_id=29, op_id=3, resource=3, duration=37),
#  Operation(task_id=20, op_id=9, resource=4, duration=29),
#  Operation(task_id=3, op_id=8, resource=5, duration=38),
#  Operation(task_id=50, op_id=0, resource=10, duration=36),
#  Operation(task_id=23, op_id=6, resource=6, duration=30),
#  Operation(task_id=37, op_id=2, resource=10, duration=14),
#  Operation(task_id=17, op_id=1, resource=9, duration=14),
#  Operation(task_id=7, op_id=0, resource=10, duration=48),
#  Operation(task_id=50, op_id=8, resource=7, duration=27),
#  Operation(task_id=23, op_id=9, resource=8, duration=17),
#  Operation(task_id=37, op_id=8, resource=9, duration=23),
#  Operation(task_id=44, op_id=0, resource=4, duration=18),
#  Operation(task_id=31, op_id=9, resource=5, duration=36),
#  Operation(task_id=17, op_id=4, resource=2, duration=35),
#  Operation(task_id=15, op_id=7, resource=4, duration=47),
#  Operation(task_id=34, op_id=8, resource=8, duration=17),
#  Operation(task_id=21, op_id=1, resource=3, duration=37),
#  Operation(task_id=43, op_id=3, resource=8, duration=18),
#  Operation(task_id=22, op_id=10, resource=2, duration=36),
#  Operation(task_id=44, op_id=5, resource=5, duration=48),
#  Operation(task_id=42, op_id=1, resource=6, duration=36),
#  Operation(task_id=21, op_id=3, resource=10, duration=27),
#  Operation(task_id=20, op_id=8, resource=5, duration=36),
#  Operation(task_id=13, op_id=6, resource=4, duration=44),
#  Operation(task_id=38, op_id=2, resource=10, duration=18),
#  Operation(task_id=36, op_id=7, resource=3, duration=24),
#  Operation(task_id=46, op_id=3, resource=7, duration=27),
#  Operation(task_id=35, op_id=1, resource=9, duration=30),
#  Operation(task_id=6, op_id=4, resource=3, duration=25),
#  Operation(task_id=7, op_id=8, resource=8, duration=47),
#  Operation(task_id=12, op_id=7, resource=4, duration=19),
#  Operation(task_id=33, op_id=7, resource=5, duration=49),
#  Operation(task_id=48, op_id=3, resource=2, duration=49),
#  Operation(task_id=14, op_id=6, resource=6, duration=28),
#  Operation(task_id=38, op_id=3, resource=4, duration=19),
#  Operation(task_id=11, op_id=8, resource=1, duration=16),
#  Operation(task_id=13, op_id=10, resource=3, duration=50),
#  Operation(task_id=47, op_id=5, resource=8, duration=17),
#  Operation(task_id=28, op_id=3, resource=1, duration=20),
#  Operation(task_id=3, op_id=0, resource=5, duration=24),
#  Operation(task_id=2, op_id=8, resource=1, duration=15),
#  Operation(task_id=10, op_id=1, resource=4, duration=46),
#  Operation(task_id=42, op_id=7, resource=2, duration=28),
#  Operation(task_id=15, op_id=10, resource=1, duration=30),
#  Operation(task_id=14, op_id=9, resource=9, duration=22),
#  Operation(task_id=9, op_id=7, resource=8, duration=40),
#  Operation(task_id=2, op_id=1, resource=10, duration=13),
#  Operation(task_id=7, op_id=2, resource=7, duration=40),
#  Operation(task_id=8, op_id=2, resource=1, duration=36),
#  Operation(task_id=20, op_id=5, resource=5, duration=16),
#  Operation(task_id=1, op_id=9, resource=8, duration=39),
#  Operation(task_id=50, op_id=7, resource=3, duration=40),
#  Operation(task_id=34, op_id=0, resource=1, duration=18),
#  Operation(task_id=5, op_id=8, resource=7, duration=43),
#  Operation(task_id=46, op_id=8, resource=5, duration=13),
#  Operation(task_id=34, op_id=10, resource=1, duration=34),
#  Operation(task_id=5, op_id=9, resource=1, duration=12),
#  Operation(task_id=22, op_id=0, resource=8, duration=34),
#  Operation(task_id=23, op_id=10, resource=9, duration=12),
#  Operation(task_id=35, op_id=7, resource=7, duration=26),
#  Operation(task_id=28, op_id=4, resource=7, duration=48),
#  Operation(task_id=29, op_id=5, resource=7, duration=23),
#  Operation(task_id=33, op_id=5, resource=6, duration=15),
#  Operation(task_id=37, op_id=1, resource=3, duration=40),
#  Operation(task_id=39, op_id=5, resource=6, duration=19),
#  Operation(task_id=50, op_id=3, resource=5, duration=18),
#  Operation(task_id=4, op_id=10, resource=9, duration=39),
#  Operation(task_id=8, op_id=0, resource=3, duration=32),
#  Operation(task_id=7, op_id=3, resource=6, duration=44),
#  Operation(task_id=49, op_id=4, resource=1, duration=20),
#  Operation(task_id=47, op_id=6, resource=7, duration=12),
#  Operation(task_id=49, op_id=1, resource=1, duration=39),
#  Operation(task_id=18, op_id=2, resource=4, duration=27),
#  Operation(task_id=29, op_id=9, resource=3, duration=28),
#  Operation(task_id=27, op_id=1, resource=1, duration=14),
#  Operation(task_id=11, op_id=1, resource=8, duration=33),
#  Operation(task_id=17, op_id=8, resource=7, duration=47),
#  Operation(task_id=15, op_id=9, resource=10, duration=18),
#  Operation(task_id=8, op_id=1, resource=3, duration=36),
#  Operation(task_id=21, op_id=9, resource=10, duration=38),
#  Operation(task_id=30, op_id=0, resource=3, duration=26),
#  Operation(task_id=27, op_id=4, resource=7, duration=21),
#  Operation(task_id=37, op_id=6, resource=1, duration=45),
#  Operation(task_id=47, op_id=1, resource=10, duration=40),
#  Operation(task_id=24, op_id=7, resource=7, duration=19),
#  Operation(task_id=29, op_id=4, resource=9, duration=28),
#  Operation(task_id=19, op_id=2, resource=4, duration=31),
#  Operation(task_id=3, op_id=2, resource=1, duration=18),
#  Operation(task_id=16, op_id=4, resource=2, duration=39),
#  Operation(task_id=49, op_id=0, resource=9, duration=26),
#  Operation(task_id=19, op_id=7, resource=7, duration=16),
#  Operation(task_id=18, op_id=0, resource=4, duration=31),
#  Operation(task_id=29, op_id=2, resource=4, duration=47),
#  Operation(task_id=13, op_id=3, resource=5, duration=20),
#  Operation(task_id=1, op_id=7, resource=7, duration=45),
#  Operation(task_id=39, op_id=1, resource=3, duration=30),
#  Operation(task_id=45, op_id=7, resource=1, duration=16),
#  Operation(task_id=31, op_id=7, resource=8, duration=19),
#  Operation(task_id=27, op_id=9, resource=7, duration=42),
#  Operation(task_id=19, op_id=6, resource=6, duration=41),
#  Operation(task_id=2, op_id=7, resource=9, duration=39),
#  Operation(task_id=14, op_id=2, resource=5, duration=35),
#  Operation(task_id=26, op_id=10, resource=1, duration=34),
#  Operation(task_id=19, op_id=4, resource=6, duration=45),
#  Operation(task_id=4, op_id=5, resource=2, duration=43),
#  Operation(task_id=17, op_id=9, resource=4, duration=27),
#  Operation(task_id=42, op_id=6, resource=7, duration=20),
#  Operation(task_id=26, op_id=9, resource=9, duration=13),
#  Operation(task_id=20, op_id=0, resource=5, duration=20),
#  Operation(task_id=24, op_id=2, resource=9, duration=29),
#  Operation(task_id=14, op_id=5, resource=1, duration=38),
#  Operation(task_id=34, op_id=1, resource=9, duration=35),
#  Operation(task_id=19, op_id=10, resource=4, duration=37),
#  Operation(task_id=50, op_id=6, resource=8, duration=46),
#  Operation(task_id=13, op_id=0, resource=3, duration=27),
#  Operation(task_id=20, op_id=2, resource=1, duration=11),
#  Operation(task_id=40, op_id=10, resource=6, duration=40),
#  Operation(task_id=38, op_id=4, resource=7, duration=18),
#  Operation(task_id=47, op_id=9, resource=2, duration=39),
#  Operation(task_id=25, op_id=0, resource=5, duration=47),
#  Operation(task_id=43, op_id=0, resource=8, duration=15),
#  Operation(task_id=12, op_id=3, resource=2, duration=38),
#  Operation(task_id=31, op_id=3, resource=10, duration=34),
#  Operation(task_id=36, op_id=5, resource=1, duration=49),
#  Operation(task_id=35, op_id=5, resource=6, duration=18),
#  Operation(task_id=7, op_id=5, resource=6, duration=16),
#  Operation(task_id=41, op_id=1, resource=10, duration=36),
#  Operation(task_id=32, op_id=4, resource=3, duration=28),
#  Operation(task_id=24, op_id=6, resource=5, duration=50),
#  Operation(task_id=12, op_id=4, resource=6, duration=17),
#  Operation(task_id=31, op_id=10, resource=9, duration=21),
#  Operation(task_id=45, op_id=10, resource=1, duration=24),
#  Operation(task_id=31, op_id=6, resource=2, duration=34),
#  Operation(task_id=33, op_id=0, resource=10, duration=48),
#  Operation(task_id=32, op_id=1, resource=10, duration=33),
#  Operation(task_id=24, op_id=3, resource=5, duration=10),
#  Operation(task_id=9, op_id=3, resource=8, duration=44),
#  Operation(task_id=32, op_id=7, resource=7, duration=44),
#  Operation(task_id=50, op_id=4, resource=2, duration=21),
#  Operation(task_id=36, op_id=6, resource=5, duration=22),
#  Operation(task_id=17, op_id=2, resource=6, duration=26),
#  Operation(task_id=26, op_id=3, resource=10, duration=14),
#  Operation(task_id=6, op_id=10, resource=9, duration=35),
#  Operation(task_id=16, op_id=7, resource=1, duration=10),
#  Operation(task_id=14, op_id=7, resource=8, duration=32),
#  Operation(task_id=27, op_id=7, resource=9, duration=20),
#  Operation(task_id=43, op_id=9, resource=4, duration=24),
#  Operation(task_id=37, op_id=3, resource=5, duration=20),
#  Operation(task_id=6, op_id=2, resource=9, duration=19),
#  Operation(task_id=9, op_id=4, resource=5, duration=38),
#  Operation(task_id=20, op_id=4, resource=8, duration=49),
#  Operation(task_id=4, op_id=9, resource=7, duration=15),
#  Operation(task_id=44, op_id=2, resource=10, duration=40),
#  Operation(task_id=36, op_id=10, resource=8, duration=36),
#  Operation(task_id=33, op_id=3, resource=10, duration=16),
#  Operation(task_id=20, op_id=3, resource=9, duration=19),
#  Operation(task_id=14, op_id=0, resource=4, duration=15),
#  Operation(task_id=24, op_id=4, resource=9, duration=21),
#  Operation(task_id=32, op_id=3, resource=7, duration=45),
#  Operation(task_id=36, op_id=9, resource=5, duration=11),
#  Operation(task_id=22, op_id=2, resource=4, duration=24),
#  Operation(task_id=26, op_id=7, resource=1, duration=49),
#  Operation(task_id=5, op_id=4, resource=10, duration=42),
#  Operation(task_id=10, op_id=8, resource=4, duration=31),
#  Operation(task_id=30, op_id=4, resource=2, duration=32),
#  Operation(task_id=27, op_id=3, resource=5, duration=16),
#  Operation(task_id=35, op_id=2, resource=7, duration=27),
#  Operation(task_id=49, op_id=6, resource=5, duration=25),
#  Operation(task_id=20, op_id=6, resource=3, duration=25),
#  Operation(task_id=7, op_id=4, resource=8, duration=35),
#  Operation(task_id=40, op_id=1, resource=10, duration=30),
#  Operation(task_id=30, op_id=10, resource=2, duration=30),
#  Operation(task_id=32, op_id=9, resource=9, duration=17),
#  Operation(task_id=24, op_id=9, resource=8, duration=41),
#  Operation(task_id=8, op_id=9, resource=6, duration=18),
#  Operation(task_id=15, op_id=2, resource=1, duration=14),
#  Operation(task_id=27, op_id=6, resource=10, duration=25),
#  Operation(task_id=1, op_id=6, resource=2, duration=18),
#  Operation(task_id=20, op_id=7, resource=7, duration=36),
#  Operation(task_id=25, op_id=9, resource=9, duration=29),
#  Operation(task_id=26, op_id=8, resource=9, duration=12),
#  Operation(task_id=46, op_id=1, resource=3, duration=10),
#  Operation(task_id=33, op_id=1, resource=6, duration=28),
#  Operation(task_id=47, op_id=8, resource=2, duration=24),
#  Operation(task_id=32, op_id=8, resource=1, duration=18),
#  Operation(task_id=23, op_id=1, resource=4, duration=33),
#  Operation(task_id=4, op_id=6, resource=7, duration=33),
#  Operation(task_id=11, op_id=7, resource=2, duration=37),
#  Operation(task_id=47, op_id=7, resource=6, duration=42),
#  Operation(task_id=8, op_id=3, resource=2, duration=21),
#  Operation(task_id=3, op_id=7, resource=7, duration=34),
#  Operation(task_id=33, op_id=6, resource=5, duration=21),
#  Operation(task_id=17, op_id=6, resource=4, duration=15),
#  Operation(task_id=25, op_id=6, resource=7, duration=26),
#  Operation(task_id=30, op_id=8, resource=4, duration=13),
#  Operation(task_id=19, op_id=1, resource=7, duration=12),
#  Operation(task_id=42, op_id=9, resource=8, duration=22),
#  Operation(task_id=23, op_id=8, resource=6, duration=42),
#  Operation(task_id=22, op_id=4, resource=3, duration=10),
#  Operation(task_id=10, op_id=0, resource=5, duration=50),
#  Operation(task_id=32, op_id=2, resource=1, duration=11),
#  Operation(task_id=12, op_id=10, resource=7, duration=23),
#  Operation(task_id=37, op_id=7, resource=6, duration=32),
#  Operation(task_id=44, op_id=10, resource=4, duration=27),
#  Operation(task_id=28, op_id=0, resource=10, duration=42),
#  Operation(task_id=13, op_id=1, resource=9, duration=22),
#  Operation(task_id=48, op_id=2, resource=3, duration=39),
#  Operation(task_id=36, op_id=0, resource=9, duration=28),
#  Operation(task_id=21, op_id=6, resource=7, duration=22),
#  Operation(task_id=48, op_id=10, resource=9, duration=31),
#  Operation(task_id=24, op_id=8, resource=8, duration=25),
#  Operation(task_id=42, op_id=3, resource=2, duration=39),
#  Operation(task_id=23, op_id=7, resource=4, duration=24),
#  Operation(task_id=9, op_id=8, resource=2, duration=38),
#  Operation(task_id=39, op_id=10, resource=1, duration=23),
#  Operation(task_id=11, op_id=2, resource=3, duration=13),
#  Operation(task_id=28, op_id=10, resource=5, duration=39),
#  Operation(task_id=41, op_id=9, resource=5, duration=20),
#  Operation(task_id=10, op_id=7, resource=10, duration=44),
#  Operation(task_id=23, op_id=5, resource=9, duration=27),
#  Operation(task_id=42, op_id=0, resource=3, duration=37),
#  Operation(task_id=35, op_id=8, resource=3, duration=39),
#  Operation(task_id=42, op_id=5, resource=10, duration=34),
#  Operation(task_id=26, op_id=1, resource=7, duration=34),
#  Operation(task_id=14, op_id=8, resource=4, duration=15),
#  Operation(task_id=46, op_id=9, resource=6, duration=28),
#  Operation(task_id=1, op_id=10, resource=5, duration=46),
#  Operation(task_id=13, op_id=5, resource=1, duration=11),
#  Operation(task_id=40, op_id=4, resource=6, duration=32),
#  Operation(task_id=2, op_id=3, resource=4, duration=29),
#  Operation(task_id=29, op_id=6, resource=2, duration=21),
#  Operation(task_id=48, op_id=0, resource=6, duration=37),
#  Operation(task_id=16, op_id=2, resource=3, duration=18),
#  Operation(task_id=10, op_id=5, resource=6, duration=49),
#  Operation(task_id=15, op_id=0, resource=10, duration=36),
#  Operation(task_id=38, op_id=1, resource=8, duration=48),
#  Operation(task_id=12, op_id=6, resource=3, duration=10),
#  Operation(task_id=3, op_id=4, resource=4, duration=17),
#  Operation(task_id=4, op_id=1, resource=5, duration=47),
#  Operation(task_id=30, op_id=2, resource=7, duration=11),
#  Operation(task_id=9, op_id=2, resource=5, duration=10),
#  Operation(task_id=28, op_id=8, resource=4, duration=14),
#  Operation(task_id=33, op_id=4, resource=10, duration=38),
#  Operation(task_id=2, op_id=6, resource=2, duration=49),
#  Operation(task_id=6, op_id=1, resource=3, duration=50),
#  Operation(task_id=17, op_id=0, resource=2, duration=20),
#  Operation(task_id=29, op_id=7, resource=7, duration=31),
#  Operation(task_id=41, op_id=6, resource=3, duration=27),
#  Operation(task_id=11, op_id=10, resource=1, duration=45),
#  Operation(task_id=18, op_id=3, resource=7, duration=26),
#  Operation(task_id=27, op_id=5, resource=7, duration=43),
#  Operation(task_id=24, op_id=1, resource=6, duration=11),
#  Operation(task_id=34, op_id=6, resource=8, duration=24),
#  Operation(task_id=27, op_id=10, resource=7, duration=11),
#  Operation(task_id=10, op_id=10, resource=5, duration=29),
#  Operation(task_id=11, op_id=0, resource=3, duration=46),
#  Operation(task_id=50, op_id=10, resource=8, duration=18),
#  Operation(task_id=22, op_id=8, resource=1, duration=20),
#  Operation(task_id=2, op_id=0, resource=5, duration=17),
#  Operation(task_id=29, op_id=0, resource=4, duration=12),
#  Operation(task_id=41, op_id=4, resource=7, duration=36),
#  Operation(task_id=10, op_id=2, resource=1, duration=20),
#  Operation(task_id=7, op_id=9, resource=3, duration=17),
#  Operation(task_id=40, op_id=2, resource=10, duration=34),
#  Operation(task_id=45, op_id=3, resource=1, duration=15),
#  Operation(task_id=43, op_id=6, resource=3, duration=17),
#  Operation(task_id=16, op_id=1, resource=1, duration=21),
#  Operation(task_id=27, op_id=8, resource=10, duration=49),
#  Operation(task_id=45, op_id=6, resource=4, duration=37),
#  Operation(task_id=1, op_id=1, resource=3, duration=49),
#  Operation(task_id=29, op_id=10, resource=2, duration=47),
#  Operation(task_id=30, op_id=1, resource=6, duration=48),
#  Operation(task_id=46, op_id=10, resource=8, duration=11),
#  Operation(task_id=4, op_id=4, resource=7, duration=27),
#  Operation(task_id=25, op_id=10, resource=10, duration=12),
#  Operation(task_id=43, op_id=7, resource=8, duration=45),
#  Operation(task_id=24, op_id=10, resource=10, duration=34),
#  Operation(task_id=4, op_id=8, resource=1, duration=35),
#  Operation(task_id=21, op_id=2, resource=7, duration=10),
#  Operation(task_id=8, op_id=6, resource=7, duration=47),
#  Operation(task_id=35, op_id=10, resource=2, duration=50),
#  Operation(task_id=19, op_id=3, resource=3, duration=24),
#  Operation(task_id=11, op_id=5, resource=4, duration=39),
#  Operation(task_id=46, op_id=0, resource=7, duration=21),
#  Operation(task_id=6, op_id=3, resource=3, duration=28),
#  Operation(task_id=34, op_id=3, resource=9, duration=31),
#  Operation(task_id=13, op_id=7, resource=6, duration=44),
#  Operation(task_id=3, op_id=9, resource=1, duration=29),
#  Operation(task_id=20, op_id=1, resource=8, duration=12),
#  Operation(task_id=50, op_id=2, resource=4, duration=16),
#  Operation(task_id=34, op_id=4, resource=2, duration=21),
#  Operation(task_id=1, op_id=8, resource=6, duration=10),
#  Operation(task_id=47, op_id=2, resource=9, duration=24),
#  Operation(task_id=28, op_id=7, resource=8, duration=40),
#  Operation(task_id=40, op_id=8, resource=2, duration=13),
#  Operation(task_id=36, op_id=8, resource=2, duration=15),
#  Operation(task_id=43, op_id=5, resource=9, duration=41)]
